# %% [markdown]
# ##### Lesson 1
# ##### pip install pandas

# %%
import pandas as pd

# %% [markdown]
# #### Pandas series : a list 1- dimensional

# %%
s1=[1,2,3,4,5,6]
s2=['a','b','c']

# %% [markdown]
# ##### Pandas Dataframe: 2+ dimensional rows and columns

# %%
series1=pd.Series(s1)

# %% [markdown]
# #### fetch the datafile

# %%
df= pd.read_csv("../datasets/dirty.csv")

# %% [markdown]
# #### Converting to a dataframe

# %%
df=pd.DataFrame(df)
